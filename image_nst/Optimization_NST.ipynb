# %% [markdown]
# <a href="https://colab.research.google.com/github/aymanemoataz/pytorch-segment-nst/blob/main/Optimization_NST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt

# %% [markdown]
# Checking the GPU configuration and the RAM run-time

# %%
#GPU configuration
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

#RAM run-time
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Fri Dec 31 02:02:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## cloning @gordicalesksa pytorch nst repo

# %%
# !git clone https://github.com/gordicaleksa/pytorch-neural-style-transfer.git
# Out:
# Cloning into 'pytorch-neural-style-transfer'...
# remote: Enumerating objects: 469, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 469 (delta 10), reused 15 (delta 5), pack-reused 444
# Receiving objects: 100% (469/469), 37.11 MiB | 13.63 MiB/s, done.
# Resolving deltas: 100% (203/203), done.

# %% [markdown]
# **neural_style_transfer.py**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Create small videos of your content  and style reconstruction

# %%
# !python /content/pytorch-neural-style-transfer/neural_style_transfer.py
# Out:
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=9364937113600.0000, content_loss=      0.0000, style loss=9364920000000.0000, tv loss=16684927.0000
# L-BFGS | iteration: 001, total loss=9364935016448.0000, content_loss=      0.0001, style loss=9364918080000.0000, tv loss=16684927.0000
# L-BFGS | iteration: 002, total loss=9364930822144.0000, content_loss=      0.0003, style loss=9364914240000.0000, tv loss=16684930.0000
# L-BFGS | iteration: 003, total loss=9364929773568.0000, content_loss=      0.0004, style loss=9364913280000.0000, tv loss=16684930.0000
# L-BFGS | iteration: 004, total loss=9364929773568.0000, content_loss=      0.0004, style loss=9364913280000.0000, tv loss=16684930.0000
# L-BFGS | iteration: 005, total loss=9364929773568.0000, content_loss=      0.0004, style loss=9364913280000.0000, tv loss=16684930.0000
# ...

# %%
from google.colab import files

# %%
files.download('/content/pytorch-neural-style-transfer/data/output-images/combined_fiat_vg_la_cafe/out.mp4')

# %% [markdown]
# 1/0m

# %%
# !python /content/pytorch-neural-style-transfer/reconstruct_image_from_representation.py
# Out:
# Iteration: 0, current style loss=189290400.0
# Iteration: 1, current style loss=189290304.0
# Iteration: 2, current style loss=189290224.0
# Iteration: 3, current style loss=189290192.0
# Iteration: 4, current style loss=189289312.0
# Iteration: 5, current style loss=189284432.0
# Iteration: 6, current style loss=189230784.0
# Iteration: 7, current style loss=188695616.0
# Iteration: 8, current style loss=186042736.0
# Iteration: 9, current style loss=159576048.0
# Iteration: 10, current style loss=59171792.0
# Iteration: 11, current style loss=43279108.0
# Iteration: 12, current style loss=33241800.0
# Iteration: 13, current style loss=25365602.0
# Iteration: 14, current style loss=16899572.0
# Iteration: 15, current style loss=12530083.0
# Iteration: 16, current style loss=10522452.0
# Iteration: 17, current style loss=8269810.0
# Iteration: 18, current style loss=6608970.5
# Iteration: 19, current style loss=5999439.5
# Iteration: 20, current style loss=5271064.5
# ...

# %%
# !python /content/pytorch-neural-style-transfer/neural_style_transfer.py
# Out:
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=9873051877376.0000, content_loss=      0.0000, style loss=9873033600000.0000, tv loss=17760920.0000
# L-BFGS | iteration: 001, total loss=9873049780224.0000, content_loss=      0.0001, style loss=9873031680000.0000, tv loss=17760920.0000
# L-BFGS | iteration: 002, total loss=9873048731648.0000, content_loss=      0.0001, style loss=9873030720000.0000, tv loss=17760920.0000
# L-BFGS | iteration: 003, total loss=9873049780224.0000, content_loss=      0.0001, style loss=9873031680000.0000, tv loss=17760920.0000
# L-BFGS | iteration: 004, total loss=         nan, content_loss=         nan, style loss=         nan, tv loss=         nan
# L-BFGS | iteration: 005, total loss=         nan, content_loss=         nan, style loss=         nan, tv loss=         nan
# L-BFGS | iteration: 006, total loss=         nan, content_loss=         nan, style loss=         nan, tv loss=         nan
# ...
